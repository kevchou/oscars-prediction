# %%
import pandas as pd

# %%
bom = pd.read_csv('bom_oscars.csv')

bafta = pd.read_csv('bafta.csv')
bafta['Year'] = bafta['Year'] - 1 # Year is offset by 1. Need to correct

dga = pd.read_csv('dga.csv')[['Year', 'Movie']] # Don't need the director column

pga = pd.read_csv('pga.csv')

gg_drama = pd.read_csv('gg_drama.csv')
gg_drama['Year'] = gg_drama['Year'] - 1

gg_comedy = pd.read_csv('gg_comedy.csv')
gg_comedy['Year'] = gg_comedy['Year'] - 1

# %%
# Merge with BAFTA awards
df1 = bom.merge(bafta, how='left', 
                left_on=bom['Movie'].apply(lambda x: x.lower()),
                right_on=bafta['Movie'].apply( lambda x: x.lower()),
                suffixes=['', '_bafta'])

df1['BAFTA'] = df1['Movie_bafta'].isnull().apply(lambda x: 0 if x else 1)
del df1['Movie_bafta'], df1['Year_bafta']

# %%
# Merge with DGA awards
df2 = df1.merge(dga, how='left',
               left_on=df1['Movie'],
               right_on=dga['Movie'],
               suffixes=['', '_dga'])

df2['DGA'] = df2['Movie_dga'].isnull().apply(lambda x: 0 if x else 1)
del df2['Movie_dga'], df2['Year_dga']

# %%
# Merge with PGA awards
df3 = df2.merge(pga, how='left',
               left_on=df2['Movie'],
               right_on=pga['Movie'],
               suffixes=['', '_pga'])

df3['PGA'] = df3['Movie_pga'].isnull().apply(lambda x: 0 if x else 1)
del df3['Movie_pga'], df3['Year_pga']

# %%
# Merge with GG Comedy awards
df4 = df3.merge(gg_comedy, how='left',
               left_on=df3['Movie'],
               right_on=gg_comedy['Movie'],
               suffixes=['', '_ggc'])

df4['GGC'] = df4['Movie_ggc'].isnull().apply(lambda x: 0 if x else 1)
del df4['Movie_ggc'], df4['Year_ggc']

# %%
# Merge with GG Drama awards
df5 = df4.merge(gg_drama, how='left',
               left_on=df4['Movie'],
               right_on=gg_drama['Movie'],
               suffixes=['', '_ggd'])

df5['GGD'] = df5['Movie_ggd'].isnull().apply(lambda x: 0 if x else 1)
del df5['Movie_ggd'], df5['Year_ggd']

# %%
oscars = df5

# %%
def normalize_column_by_year(df, column):
    normalized = df.groupby(['Year']).apply(lambda x: x[column] / x[column].mean())
    normalized.index = [x[1] for x in normalized.index]
    
    return normalized

oscars['Post-Nom Gross'] = normalize_column_by_year(oscars, 'Post-Nom Gross')
oscars['Pre-Nom Gross'] = normalize_column_by_year(oscars, 'Pre-Nom Gross')
oscars['Post-Nom Theatres'] = normalize_column_by_year(oscars, 'Post-Nom Theatres')
oscars['Pre-Nom Theatres'] = normalize_column_by_year(oscars, 'Pre-Nom Theatres')

# %%
oscars.to_csv('final_dataset.csv', index=False)

# %%
# Test to see if PGA and DGA awards are oscar nominated movies

for year in df1['Year'].unique():
    
    ggd_winner = gg_drama[gg_drama['Year'] == year]['Movie']
    ggc_winner = gg_comedy[gg_comedy['Year'] == year]['Movie']
    oscar_noms = df1[df1['Year'] == year]['Movie']
    
    print('------- {:} -------'.format(year))
    if len(ggd_winner) > 0:
        print("GGDrama Winner: ", ggd_winner.iloc[0], ". Nominated for oscars:", ggd_winner.iloc[0] in oscar_noms.tolist())
        
    if len(ggc_winner) > 0:
        print("GGComedy Winner: ", ggc_winner.iloc[0], ". Nominated for oscars:", ggc_winner.iloc[0] in oscar_noms.tolist())
        
    print(oscar_noms)
    print()
# Out:
# ------- 1982 -------
# GGDrama Winner:  E. T.: The Extra-Terrestrial . Nominated for oscars: False
# GGComedy Winner:  Tootsie . Nominated for oscars: True
# 0    E.T.: The Extra-Terrestrial
# 1                        Tootsie
# 2                    The Verdict
# 3                         Gandhi
# 4                        Missing
# Name: Movie, dtype: object
#
# ------- 1983 -------
# GGDrama Winner:  Terms of Endearment . Nominated for oscars: True
# GGComedy Winner:  Yentl . Nominated for oscars: False
# 5    Terms of Endearment
# 6          The Big Chill
# 7        The Right Stuff
# 8         Tender Mercies
# 9            The Dresser
# Name: Movie, dtype: object
#
# ------- 1984 -------
# GGDrama Winner:  Amadeus . Nominated for oscars: True
# GGComedy Winner:  Romancing The Stone . Nominated for oscars: False
# 10                Amadeus
# 11    Places in the Heart
# 12     The Killing Fields
# 13     A Passage to India
# 14      A Soldier's Story
# Name: Movie, dtype: object
#
# ------- 1985 -------
# GGDrama Winner:  Out Of Africa . Nominated for oscars: False
# GGComedy Winner:  Prizzi's Honor . Nominated for oscars: True
# 15            The Color Purple
# 16               Out of Africa
# 17                     Witness
# 18              Prizzi's Honor
# 19    Kiss of the Spider Woman
# Name: Movie, dtype: object
#
# ------- 1986 -------
# GGDrama Winner:  Platoon . Nominated for oscars: True
# GGComedy Winner:  Hannah and Her Sisters . Nominated for oscars: True
# 20                     Platoon
# 21      Hannah and Her Sisters
# 22    Children of a Lesser God
# 23          A Room with a View
# 24                 The Mission
# Name: Movie, dtype: object
#
# ------- 1987 -------
# GGDrama Winner:  The Last Emperor . Nominated for oscars: True
# GGComedy Winner:  Hope and Glory . Nominated for oscars: True
# 25    Fatal Attraction
# 26          Moonstruck
# 27      Broadcast News
# 28    The Last Emperor
# 29      Hope and Glory
# Name: Movie, dtype: object
#
# ------- 1988 -------
# GGDrama Winner:  Rain Man . Nominated for oscars: True
# GGComedy Winner:  Working Girl . Nominated for oscars: True
# 30                  Rain Man
# 31              Working Girl
# 32        Dangerous Liaisons
# 33       Mississippi Burning
# 34    The Accidental Tourist
# Name: Movie, dtype: object
#
# ------- 1989 -------
# GGDrama Winner:  Born on the Fourth of July . Nominated for oscars: True
# GGComedy Winner:  Driving Miss Daisy . Nominated for oscars: True
# 35            Driving Miss Daisy
# 36            Dead Poets Society
# 37    Born on the Fourth of July
# 38               Field of Dreams
# 39                  My Left Foot
# Name: Movie, dtype: object
#
# ------- 1990 -------
# GGDrama Winner:  Dances With Wolves . Nominated for oscars: False
# GGComedy Winner:  Green Card . Nominated for oscars: False
# 40                     Ghost
# 41        Dances with Wolves
# 42    The Godfather Part III
# 43                Awakenings
# 44                Goodfellas
# Name: Movie, dtype: object
#
# ------- 1991 -------
# GGDrama Winner:  Bugsy . Nominated for oscars: True
# GGComedy Winner:  Beauty and the Beast . Nominated for oscars: True
# 45        Beauty and the Beast
# 46    The Silence of the Lambs
# 47         The Prince of Tides
# 48                         JFK
# 49                       Bugsy
# Name: Movie, dtype: object
#
# ------- 1992 -------
# GGDrama Winner:  Scent of a Woman . Nominated for oscars: True
# GGComedy Winner:  The Player . Nominated for oscars: False
# 50      A Few Good Men
# 51          Unforgiven
# 52    Scent of a Woman
# 53     The Crying Game
# 54         Howards End
# Name: Movie, dtype: object
#
# ------- 1993 -------
# GGDrama Winner:  Schindler's List . Nominated for oscars: True
# GGComedy Winner:  Mrs. Doubtfire . Nominated for oscars: False
# 55                 The Fugitive
# 56             Schindler's List
# 57                    The Piano
# 58    In the Name of the Father
# 59       The Remains of the Day
# Name: Movie, dtype: object
#
# ------- 1994 -------
# GGDrama Winner:  Forrest Gump . Nominated for oscars: True
# GGComedy Winner:  The Lion King . Nominated for oscars: False
# 60                   Forrest Gump
# 61                   Pulp Fiction
# 62    Four Weddings and a Funeral
# 63       The Shawshank Redemption
# 64                      Quiz Show
# Name: Movie, dtype: object
#
# ------- 1995 -------
# GGDrama Winner:  Sense and Sensibility . Nominated for oscars: True
# GGComedy Winner:  Babe . Nominated for oscars: True
# 65                Apollo 13
# 66               Braveheart
# 67                     Babe
# 68    Sense and Sensibility
# 69               Il Postino
# Name: Movie, dtype: object
#
# ------- 1996 -------
# GGDrama Winner:  The English Patient . Nominated for oscars: True
# GGComedy Winner:  Evita . Nominated for oscars: False
# 70          Jerry Maguire
# 71    The English Patient
# 72                  Shine
# 73                  Fargo
# 74         Secrets & Lies
# Name: Movie, dtype: object
#
# ------- 1997 -------
# GGDrama Winner:  Titanic . Nominated for oscars: True
# GGComedy Winner:  As Good as It Gets . Nominated for oscars: True
# 75               Titanic
# 76    As Good as It Gets
# 77     Good Will Hunting
# 78     L.A. Confidential
# 79        The Full Monty
# Name: Movie, dtype: object
#
# ------- 1998 -------
# GGDrama Winner:  Saving Private Ryan . Nominated for oscars: True
# GGComedy Winner:  Shakespeare in Love . Nominated for oscars: True
# 80    Saving Private Ryan
# 81    Shakespeare in Love
# 82      Life Is Beautiful
# 83      The Thin Red Line
# 84             Elizabeth
# Name: Movie, dtype: object
#
# ------- 1999 -------
# GGDrama Winner:  American Beauty . Nominated for oscars: True
# GGComedy Winner:  Toy Story 2 . Nominated for oscars: False
# 85          The Sixth Sense
# 86           The Green Mile
# 87          American Beauty
# 88    The Cider House Rules
# 89              The Insider
# Name: Movie, dtype: object
#
# ------- 2000 -------
# GGDrama Winner:  Gladiator . Nominated for oscars: True
# GGComedy Winner:  Almost Famous . Nominated for oscars: False
# 90                         Gladiator
# 91    Crouching Tiger, Hidden Dragon
# 92                   Erin Brockovich
# 93                           Traffic
# 94                          Chocolat
# Name: Movie, dtype: object
#
# ------- 2001 -------
# GGDrama Winner:  A Beautiful Mind . Nominated for oscars: True
# GGComedy Winner:  Moulin Rouge! . Nominated for oscars: True
# 95    The Lord of the Rings: The Fellowship of the Ring
# 96                                     A Beautiful Mind
# 97                                        Moulin Rouge!
# 98                                         Gosford Park
# 99                                       In the Bedroom
# Name: Movie, dtype: object
#
# ------- 2002 -------
# GGDrama Winner:  The Hours . Nominated for oscars: True
# GGComedy Winner:  Chicago . Nominated for oscars: True
# 100    The Lord of the Rings: The Two Towers
# 101                                  Chicago
# 102                        Gangs of New York
# 103                                The Hours
# 104                              The Pianist
# Name: Movie, dtype: object
#
# ------- 2003 -------
# GGDrama Winner:  The Lord of the Rings: The Return of the King . Nominated for oscars: True
# GGComedy Winner:  Lost in Translation . Nominated for oscars: True
# 105      The Lord of the Rings: The Return of the King
# 106                                         Seabiscuit
# 107    Master and Commander: The Far Side of the World
# 108                                       Mystic River
# 109                                Lost in Translation
# Name: Movie, dtype: object
#
# ------- 2004 -------
# GGDrama Winner:  The Aviator . Nominated for oscars: True
# GGComedy Winner:  Sideways . Nominated for oscars: True
# 110            The Aviator
# 111    Million Dollar Baby
# 112                    Ray
# 113               Sideways
# 114      Finding Neverland
# Name: Movie, dtype: object
#
# ------- 2005 -------
# GGDrama Winner:  Brokeback Mountain . Nominated for oscars: True
# GGComedy Winner:  Walk The Line . Nominated for oscars: False
# 115            Brokeback Mountain
# 116                         Crash
# 117                        Munich
# 118    Good Night, and Good Luck.
# 119                        Capote
# Name: Movie, dtype: object
#
# ------- 2006 -------
# GGDrama Winner:  Babel . Nominated for oscars: True
# GGComedy Winner:  Dreamgirls . Nominated for oscars: False
# 120             The Departed
# 121     Little Miss Sunshine
# 122                The Queen
# 123                    Babel
# 124    Letters from Iwo Jima
# Name: Movie, dtype: object
#
# ------- 2007 -------
# GGDrama Winner:  Atonement . Nominated for oscars: True
# GGComedy Winner:  Sweeney Todd: The Demon Barber of Fleet Street . Nominated for oscars: False
# 125                      Juno
# 126    No Country for Old Men
# 127                 Atonement
# 128           Michael Clayton
# 129       There Will Be Blood
# Name: Movie, dtype: object
#
# ------- 2008 -------
# GGDrama Winner:  Slumdog Millionaire . Nominated for oscars: True
# GGComedy Winner:  Vicky Cristina Barcelona . Nominated for oscars: False
# 130                    Slumdog Millionaire
# 131    The Curious Case of Benjamin Button
# 132                             The Reader
# 133                                   Milk
# 134                            Frost/Nixon
# Name: Movie, dtype: object
#
# ------- 2009 -------
# GGDrama Winner:  Avatar . Nominated for oscars: True
# GGComedy Winner:  The Hangover . Nominated for oscars: False
# 135                                             Avatar
# 136                                                 Up
# 137                                     The Blind Side
# 138                               Inglourious Basterds
# 139                                         District 9
# 140                                      Up in the Air
# 141    Precious: Based on the Novel "Push" by Sapphire
# 142                                    The Hurt Locker
# 143                                       An Education
# 144                                      A Serious Man
# Name: Movie, dtype: object
#
# ------- 2010 -------
# GGDrama Winner:  The Social Network . Nominated for oscars: True
# GGComedy Winner:  The Kids Are All Right . Nominated for oscars: True
# 145               Toy Story 3
# 146                 Inception
# 147                 True Grit
# 148         The King's Speech
# 149                Black Swan
# 150        The Social Network
# 151               The Fighter
# 152    The Kids Are All Right
# 153                 127 Hours
# 154             Winter's Bone
# Name: Movie, dtype: object
#
# ------- 2011 -------
# GGDrama Winner:  The Descendants . Nominated for oscars: True
# GGComedy Winner:  The Artist . Nominated for oscars: True
# 155                             The Help
# 156                      The Descendants
# 157                            War Horse
# 158                            Moneyball
# 159                                 Hugo
# 160                    Midnight in Paris
# 161                           The Artist
# 162    Extremely Loud & Incredibly Close
# 163                     The Tree of Life
# Name: Movie, dtype: object
#
# ------- 2012 -------
# GGDrama Winner:  Argo . Nominated for oscars: True
# GGComedy Winner:  Les Miserables (2012) . Nominated for oscars: True
# 164                        Lincoln
# 165               Django Unchained
# 166          Les Miserables (2012)
# 167                           Argo
# 168        Silver Linings Playbook
# 169                     Life of Pi
# 170               Zero Dark Thirty
# 171    Beasts of the Southern Wild
# 172                          Amour
# Name: Movie, dtype: object
#
# ------- 2013 -------
# GGDrama Winner:  12 Years a Slave . Nominated for oscars: True
# GGComedy Winner:  American Hustle . Nominated for oscars: True
# 173                    Gravity
# 174            American Hustle
# 175    The Wolf of Wall Street
# 176           Captain Phillips
# 177           12 Years a Slave
# 178                  Philomena
# 179         Dallas Buyers Club
# 180                 Her (2013)
# 181                   Nebraska
# Name: Movie, dtype: object
#
# ------- 2014 -------
# GGDrama Winner:  Boyhood . Nominated for oscars: True
# GGComedy Winner:  The Grand Budapest Hotel . Nominated for oscars: True
# 182             American Sniper
# 183          The Imitation Game
# 184    The Grand Budapest Hotel
# 185                       Selma
# 186                     Birdman
# 187    The Theory of Everything
# 188                     Boyhood
# 189                    Whiplash
# Name: Movie, dtype: object
#
# ------- 2015 -------
# GGDrama Winner:  The Revenant . Nominated for oscars: True
# GGComedy Winner:  The Martian . Nominated for oscars: True
# 190           The Martian
# 191          The Revenant
# 192    Mad Max: Fury Road
# 193       Bridge of Spies
# 194         The Big Short
# 195             Spotlight
# 196              Brooklyn
# 197                  Room
# Name: Movie, dtype: object
#
# ------- 2016 -------
# GGDrama Winner:  Moonlight (2016) . Nominated for oscars: True
# GGComedy Winner:  La La Land . Nominated for oscars: True
# 198           Hidden Figures
# 199               La La Land
# 200                  Arrival
# 201            Hacksaw Ridge
# 202                   Fences
# 203    Manchester by the Sea
# 204                     Lion
# 205       Hell or High Water
# 206         Moonlight (2016)
# Name: Movie, dtype: object

# %%
dga_winner
# Out:
# 'Gandhi'

# %%
# Out:
# True

# %%
# Out:
# 'Gandhi'
